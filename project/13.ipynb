# %%
import pandas as pd
df = pd.read_excel('D:\py_study\project\네이버보고서.xls')
df.head()
# Out:
#   캠페인보고서(2019.02.01.~2019.04.30.),ftasia Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0                                   광고그룹        키워드        노출수        클릭수
# 1              올인원 패키지 : 디자인 툴_파워컨텐츠_포토샵          -    2319456       9606
# 2                    올인원 패키지 : 업무자동화_VBA          -     767491       8058
# 3                  ㅍAOP 전체_중복키워드_디자인(삭제)       일러스트    1137840        324
# 4             올인원 패키지 : 데이터 분석 입문 온라인_파콘          -     694106     1863.6
#
#   Unnamed: 4       Unnamed: 5    Unnamed: 6
# 0     클릭률(%)  평균클릭비용(VAT포함,원)  총비용(VAT포함,원)
# 1   0.414149          261.549       2512444
# 2    1.04991          295.975       2384965
# 3   0.028475          4841.66       1568699
# 4   0.268489          630.593       1175174

# %% [markdown]
# # 첫번째 행 삭제

# %%
# 첫번째 행 삭제
df = pd.read_excel('D:\py_study\project\네이버보고서.xls', skiprows=[0])
df.head()
# Out:
#                          광고그룹   키워드      노출수     클릭수    클릭률(%)  \
# 0   올인원 패키지 : 디자인 툴_파워컨텐츠_포토샵     -  2319456  9606.0  0.414149
# 1         올인원 패키지 : 업무자동화_VBA     -   767491  8058.0  1.049915
# 2       ㅍAOP 전체_중복키워드_디자인(삭제)  일러스트  1137840   324.0  0.028475
# 3  올인원 패키지 : 데이터 분석 입문 온라인_파콘     -   694106  1863.6  0.268489
# 4                     3. html  HTML  9626374   813.6  0.008452
#
#    평균클릭비용(VAT포함,원)  총비용(VAT포함,원)
# 0       261.549448       2512444
# 1       295.974808       2384965
# 2      4841.663580       1568699
# 3       630.593475       1175174
# 4      1408.435349       1145903

# %% [markdown]
# # 결측치 확인

# %%
# 열 단위
df.isnull().sum()
# Out:
# 광고그룹               0
# 키워드                0
# 노출수                0
# 클릭수                0
# 클릭률(%)             0
# 평균클릭비용(VAT포함,원)    0
# 총비용(VAT포함,원)       0
# dtype: int64

# %%
# 행 단위
df.isnull().sum(axis=1)
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1376    0
# 1377    0
# 1378    0
# 1379    0
# 1380    0
# Length: 1381, dtype: int64

# %% [markdown]
# # 광고그룹 기준 분석
# as-is: 키워드 기준 분석: 키워드의 노출수/클릭수/총비용
#
# to-be: 광고그룹 기준 분석: 데이터의 구성을 광고그룹 기준으로 변경해야 함, 광고그룹의 노출수/클릭수/총비용

# %%
df_group = df.groupby('광고그룹')
df_group

# %%
df.groupby('광고그룹').count()
# Out:
#                          키워드  노출수  클릭수  클릭률(%)  평균클릭비용(VAT포함,원)  총비용(VAT포함,원)
# 광고그룹
# #000_마케팅 전체_main          48   48   48      48               48            48
# 001.BASIC DESIGN           9    9    9       9                9             9
# 001.데이터분석/ 통계             10   10   10      10               10            10
# 002.R                      9    9    9       9                9             9
# 002.UX/UI                  5    5    5       5                5             5
# ...                      ...  ...  ...     ...              ...           ...
# 포토샵 유치원_일러스트레이터 유치원       13   13   13      13               13            13
# 프로그래밍 유치원                  8    8    8       8                8             8
# 프로그래밍 전체                  12   12   12      12               12            12
# 프로그래밍 전체_파워컨텐츠_블록체인(삭제)    3    3    3       3                3             3
# 프론트엔드 개발 스쿨 12기_기존 키워드     1    1    1       1                1             1
#
# [186 rows x 6 columns]

# %%
df.groupby('광고그룹').mean()
# Out:
#                                   노출수          클릭수    클릭률(%)  평균클릭비용(VAT포함,원)  \
# 광고그룹
# #000_마케팅 전체_main         14780.145833     8.400000  0.183898       625.086295
# 001.BASIC DESIGN          5738.555556     6.800000  0.232924       298.693822
# 001.데이터분석/ 통계             3715.000000    20.280000  0.890571      1021.473357
# 002.R                    13413.777778     8.533333  0.111199       360.038462
# 002.UX/UI                 3090.800000     4.080000  0.089340        69.928571
# ...                               ...          ...       ...              ...
# 포토샵 유치원_일러스트레이터 유치원      72092.692308    16.707692  0.050832       648.327517
# 프로그래밍 유치원                 5921.625000     7.800000  0.224738      2032.326389
# 프로그래밍 전체                 90375.000000     9.200000  0.024037       123.881559
# 프로그래밍 전체_파워컨텐츠_블록체인(삭제)  65353.333333  2344.400000  3.643359       192.773927
# 프론트엔드 개발 스쿨 12기_기존 키워드    2015.000000     2.400000  0.119107        64.166667
#
# ...
